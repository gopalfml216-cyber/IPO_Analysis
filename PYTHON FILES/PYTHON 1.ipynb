# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ipo_data.csv')

# %%
df
# Out:
#          Date         IPO Name  \
# 0    29-07-21    Tatva Chintan
# 1    23-07-21           Zomato
# 2    19-07-21    Clean Science
# 3    19-07-21        G R Infra
# 4    07-07-21  India Pesticide
# ..        ...              ...
# 259  19-02-10      Thangamayil
# 260  15-02-10  Vascon Engineer
# 261  15-02-10    Syncom Health
# 262  08-02-10    Jubilant Food
# 263  03-02-10    Infinite Comp
#
#                                                Profile  \
# 0    https://www.moneycontrol.com/ipo/tatva-chintan...
# 1     https://www.moneycontrol.com/ipo/zomato_Z01.html
# 2    https://www.moneycontrol.com/ipo/clean-science...
# 3    https://www.moneycontrol.com/ipo/g-r-infra_I13...
# 4    https://www.moneycontrol.com/ipo/india-pestici...
# ..                                                 ...
# 259  https://www.moneycontrol.com/ipo/thangamayil_T...
# 260  https://www.moneycontrol.com/ipo/vascon-engine...
# 261  https://www.moneycontrol.com/ipo/syncom-health...
# ...

# %%
df.shape
# Out:
# (264, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    264 non-null    object
#  1   IPO Name                264 non-null    object
#  2   Profile                 264 non-null    object
#  3   Issue Size (in crores)  264 non-null    float64
#  4   QIB                     264 non-null    float64
#  5   HNI                     264 non-null    float64
#  6   RII                     264 non-null    float64
#  7   Total                   264 non-null    float64
#  8   Issue                   264 non-null    float64
#  9   Listing Open            264 non-null    float64
#  10  Listing Close           264 non-null    float64
#  11  Listing Gains(%)        264 non-null    float64
#  12  CMP                     264 non-null    object
#  13  Current  Gains (%)      262 non-null    float64
# ...

# %%
df.drop(['CMP','Current  Gains (%)'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (264, 12)

# %%
df.describe()
# Out:
#        Issue Size (in crores)         QIB         HNI         RII       Total  \
# count              264.000000  264.000000  264.000000  264.000000  264.000000
# mean               978.718106   23.732841   68.798561    7.388371   25.944886
# std               1884.758112   36.880595  136.513479   11.837761   45.444680
# min                  0.000000    0.000000    0.000000    0.000000    0.000000
# 25%                144.250000    1.130000    1.210000    1.297500    1.570000
# 50%                441.225000    4.670000    5.075000    3.380000    4.845000
# 75%                903.187500   32.505000   65.112500    8.392500   33.412500
# max              15475.000000  176.850000  958.070000   77.930000  277.280000
#
#              Issue  Listing Open  Listing Close  Listing Gains(%)
# count   264.000000    264.000000     264.000000        264.000000
# mean    339.291667    403.329735     363.170152          4.290871
# std     333.874356    437.396998     417.120358         46.343783
# ...

# %%
df.columns
# Out:
# Index(['Date', 'IPO Name', 'Profile', 'Issue Size (in crores)', 'QIB', 'HNI',
#        'RII', 'Total', 'Issue', 'Listing Open', 'Listing Close',
#        'Listing Gains(%)'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    264 non-null    datetime64[ns]
#  1   IPO Name                264 non-null    object
#  2   Profile                 264 non-null    object
#  3   Issue Size (in crores)  264 non-null    float64
#  4   QIB                     264 non-null    float64
#  5   HNI                     264 non-null    float64
#  6   RII                     264 non-null    float64
#  7   Total                   264 non-null    float64
#  8   Issue                   264 non-null    float64
#  9   Listing Open            264 non-null    float64
#  10  Listing Close           264 non-null    float64
#  11  Listing Gains(%)        264 non-null    float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 24.9+ KB

# %%
df.to_excel("ipo_cleaned.xlsx", index=False)
